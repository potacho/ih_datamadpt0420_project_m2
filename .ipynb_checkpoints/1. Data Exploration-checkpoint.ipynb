# %%
# Ignore warnings :
import warnings
warnings.filterwarnings('ignore')

# Data handling
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Data Exploration
import missingno

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import set_matplotlib_formats
import cufflinks as cf
import plotly.express as px
import matplotlib.gridspec as gridspec
import plotly.graph_objects as go
import plotly.figure_factory as ff

# %%
diamonds=pd.read_csv('/home/carmencuadrado/Ironhack/ih_datamadpt0420_project_m2/diamonds_train.csv')

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ### Diamonds DataFrame overview

# %% [markdown]
# The initial dataframe is made up of 10 columns containing information on diamonds' 4Cs, their size and price

# %%
diamonds.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95

# %% [markdown]
# ### Diamonds information

# %% [markdown]
# Digging into the dataframe structure, we could assert that there are
# - apparently not null values in this dataframe
# - three columns types are present
#     - string, for the 4Cs-related characteristics,
#     - floats, for the measures variables, and
#     - integer, that applies only for the price
# - 40k entries recorded, which makes this dataframe a relevant sample for the sake of drawing conclusions on diamonds market

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
# carat      40455 non-null float64
# cut        40455 non-null object
# color      40455 non-null object
# clarity    40455 non-null object
# depth      40455 non-null float64
# table      40455 non-null float64
# price      40455 non-null int64
# x          40455 non-null float64
# y          40455 non-null float64
# z          40455 non-null float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# ### Categorical variables

# %%
diamonds.select_dtypes(['object']).columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %% [markdown]
# ### Numerical variables

# %%
diamonds.select_dtypes(['float64','int64']).columns
# Out:
# Index(['carat', 'depth', 'table', 'price', 'x', 'y', 'z'], dtype='object')

# %% [markdown]
# ### Diamonds numerical variables basic statistics

# %% [markdown]
# In the case of the diamonds' measures it is evident looking at the min value that there are outliers to be removed from the sample, as no diamond can measure 0

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean       0.797706     61.752841     57.446133   3928.444469      5.729392
# std        0.475544      1.431725      2.233535   3992.416147      1.124453
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    945.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2397.000000      5.690000
# 75%        1.040000     62.500000     59.000000   5331.000000      6.540000
# max        4.500000     79.000000     95.000000  18823.000000     10.230000
#
#                   y             z
# count  40455.000000  40455.000000
# mean       5.732819      3.537154
# std        1.146650      0.697062
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.035000
# ...

# %% [markdown]
# ### Missing/Null values

# %% [markdown]
# We can confirm that there are no null values, or better said, null values are not obvious. Actually, as we have seen in the previous section, there are invalid entries that take the value 0

# %%
diamonds.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
# %matplotlib inline
set_matplotlib_formats('svg')

# %%
missingno.matrix(diamonds,figsize=(8, 4));

# %% [markdown]
# ### Sample distribution

# %% [markdown]
# According to the graph below, "depth", "table" and "y" stand out for having numerous outliers. Throughtout our analysis, we have to identify if they are special diamonds or the are the result of data entry mistake

# %%
diamonds[['carat', 'depth', 'table', 'x', 'y', 'z']].plot(kind='box', figsize=(8, 16));

# %% [markdown]
# ### Cleaning

# %% [markdown]
# We are going to remove entries with 0 in any of the x, y or z measures

# %% [markdown]
# Entries without diameter/width

# %%
filter1=diamonds['y']==0
diamonds[diamonds['y']==0]
# Out:
#        carat      cut color clarity  depth  table  price    x    y    z
# 6465    0.71     Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0
# 26192   2.25  Premium     H     SI2   62.8   59.0  18034  0.0  0.0  0.0
# 28029   0.71     Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0
# 34423   1.14     Fair     G     VS1   57.5   67.0   6381  0.0  0.0  0.0

# %% [markdown]
# Entries without height

# %%
filter2=diamonds['z']==0
diamonds[diamonds['z']==0]
# Out:
#        carat      cut color clarity  depth  table  price     x     y    z
# 1606    1.01  Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 3945    2.02  Premium     H     VS2   62.7   53.0  18207  8.02  7.95  0.0
# 6465    0.71     Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 13839   2.80     Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.0
# 14815   1.07    Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 14891   2.18  Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 16425   2.20  Premium     H     SI1   61.2   59.0  17265  8.42  8.37  0.0
# 19856   1.00  Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 21602   1.15    Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 24795   1.10  Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 26192   2.25  Premium     H     SI2   62.8   59.0  18034  0.00  0.00  0.0
# 26978   1.01  Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# ...

# %% [markdown]
# Entries without length

# %%
filter3=diamonds['x']==0
diamonds[diamonds['x']==0]
# Out:
#        carat      cut color clarity  depth  table  price    x     y    z
# 6465    0.71     Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0
# 14815   1.07    Ideal     F     SI2   61.6   56.0   4954  0.0  6.62  0.0
# 26192   2.25  Premium     H     SI2   62.8   59.0  18034  0.0  0.00  0.0
# 28029   0.71     Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0
# 34423   1.14     Fair     G     VS1   57.5   67.0   6381  0.0  0.00  0.0

# %%
diamonds=diamonds[~((filter1) | (filter2) | (filter3))]

# %% [markdown]
# New dataframe shape

# %%
diamonds.shape
# Out:
# (40439, 10)

# %% [markdown]
# New numerical values basic statistics

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  40439.000000  40439.000000  40439.000000  40439.000000  40439.000000
# mean       0.797425     61.753013     57.445543   3926.535448      5.729616
# std        0.475257      1.431306      2.233055   3990.024501      1.122384
# min        0.200000     43.000000     43.000000    326.000000      3.770000
# 25%        0.400000     61.000000     56.000000    945.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2396.000000      5.690000
# 75%        1.040000     62.500000     59.000000   5329.500000      6.540000
# max        4.500000     79.000000     95.000000  18823.000000     10.230000
#
#                   y             z
# count  40439.000000  40439.000000
# mean       5.732897      3.538553
# std        1.145002      0.693639
# min        3.720000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.040000
# ...

# %%
diamonds.to_csv('/home/carmencuadrado/Ironhack/ih_datamadpt0420_project_m2/diamonds_cleaned.csv', index=False)

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.
